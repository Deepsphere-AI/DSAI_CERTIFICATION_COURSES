# %% [markdown]
# **Problem Statement**

# %% [markdown]
# Predicting Customer Churn or Customer leaving the business at a certain time. Companies or Organizations often face huge customer attrition or churn. When customers leave the company, they lose the revenue from these customers and lose the resources spent to acquire these customers in the first place. This is a serious concern for the companies.

# %%
import pandas as pd
from google.colab import drive

# %%
class Data_pipline_Customer_Churn:
  def __init__(self):
    self.path = ''

# Step 1: Data Collection

  def read_data_from_drive(self):
    drive.mount('/content/drive',force_remount=True)
    # !mkdir temp
    # !cp -av '/content/drive/MyDrive/Data Engineering/Intermediate/Unit-3/Source Data/Customer Churn.csv' '/content/drive/MyDrive/Data Engineering/Intermediate/Unit-3/temp/Customer Churn.csv'
    # !cp -av '/content/drive/MyDrive/Data Engineering/Intermediate/Unit-3/Source Data/Customer_Names.csv' '/content/drive/MyDrive/Data Engineering/Intermediate/Unit-3/temp/Customer_Names.csv'
    self.Customer = '/content/drive/MyDrive/Data Engineering/Intermediate/Unit-3/temp/Customer Churn.csv'
    self.Customer_Names = '/content/drive/MyDrive/Data Engineering/Intermediate/Unit-3/temp/Customer_Names.csv'

  def print_collected_data(self):
    self.vAR_df = pd.read_csv(self.Customer)
    self.vAR_df1 = pd.read_csv(self.Customer_Names)
    #print(self.vAR_df.head)
    #print(self.vAR_df1.head)

# Step 2: Data Preparation 

# The Data Preparation Steps Involves a lot of steps including Data Integration,
# data Mapping, data Transformation, Removing Duplicates, Missing Values etc. Here in this
# example we are implementing only sum of them

  def integrate_data(self):
    self.vAR_df3 = self.vAR_df.merge(self.vAR_df1, left_on='CustomerID', right_on='CustomerID')
    return self.vAR_df3.head()

  def Missing_values(self):
    self.vAR_df3.info()
    self.mean_value=self.vAR_df3['Quantity'].mean() 
    self.vAR_df3['Quantity'].fillna(value=self.mean_value, inplace=True)
    self.mean_value1=self.vAR_df3['Price'].mean() 
    self.vAR_df3['Price'].fillna(value=self.mean_value1, inplace=True)    
    #print(self.vAR_df3)

  def drop_columns(self):
    self.vAR_df4 = self.vAR_df3
    self.vAR_df4.drop(self.vAR_df4['Product'],axis=1)
    #return self.vAR_df4.head()

# Step 3: Data Provisioning 
  def Training_Test_data(self):
    vAR_X = self.vAR_df3.iloc[:,4:9]
    vAR_y = self.vAR_df3.iloc[:,9] 
    
    self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(vAR_X, vAR_y, test_size=0.2, 
                                                        random_state=42, shuffle=True)
    print(self.X_train)
    print(self.y_train)

vAR_obj = Data_pipline_Customer_Churn()
vAR_obj.read_data_from_drive()
vAR_obj.print_collected_data()
vAR_obj.integrate_data()
vAR_obj.Missing_values()
#vAR_obj.drop_columns() 
vAR_obj.Training_Test_data()
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘temp’: File exists
# '/content/drive/MyDrive/Data Engineering/Intermediate/Unit-3/Source Data/Customer Churn.csv' -> '/content/drive/MyDrive/Data Engineering/Intermediate/Unit-3/temp/Customer Churn.csv'
# '/content/drive/MyDrive/Data Engineering/Intermediate/Unit-3/Source Data/Customer_Names.csv' -> '/content/drive/MyDrive/Data Engineering/Intermediate/Unit-3/temp/Customer_Names.csv'
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 59
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CustomerID               60 non-null     int64
#  1   Product                  57 non-null     object
#  2   Supply Date              60 non-null     int64
#  3   Service Start Date       60 non-null     object
#  4   Quantity                 57 non-null     float64
#  5   Price                    57 non-null     float64
#  6   Service Call             60 non-null     int64
#  7   Service Failure Rate%    60 non-null     int64
#  8   Customer Lifetime(Days)  60 non-null     int64
#  9   Churn                    60 non-null     int64
#  10  Churn Days               60 non-null     int64
#  11  Churn Reasons            60 non-null     object
#  12  Unnamed: 12              0 non-null      float64
#  13  CustomerID.1             60 non-null     object
# dtypes: float64(3), int64(7), object(4)
# memory usage: 7.0+ KB
#       Quantity        Price  Service Call  Service Failure Rate%  \
# 31  104.000000  1246.960000            20                     10
# 3   113.000000  1354.870000            20                     10
# 52   98.000000   773.220000            15                     15
# 17   95.000000   749.550000            15                     25
# 8    88.000000   694.320000            10                     15
# 6    85.000000  1019.150000            10                     10
# 40   91.000000  1444.170000            10                      6
# 4    95.000000  1507.650000            15                     10
# 43   89.000000  1412.430000            10                     15
# 19  104.000000  1650.480000            20                     50
# 34   98.000000  1175.020000            15                     25
# 58   98.000000   773.220000            15                     10
# 25   95.000000  1507.650000            15                      6
# 56  102.000000   804.780000            20                     50
# 15  104.000000  1246.960000            20                     25
# 27  104.000000  1246.960000            20                     10
# 9    95.000000  1139.050000            15                     10
# 30   99.000000  1187.010000            15                     10
# 26   98.000000   773.220000            15                     10
# 16   91.000000  1444.170000            10                     35
# 24   88.000000  1055.120000            10                      6
# 55   97.000000   765.330000            15                     25
# 11  101.000000   796.890000            20                     25
# 32  102.000000  1222.980000            20                     10
# 53   94.000000   741.660000            10                     25
# 41  105.000000  1666.350000            20                     10
# 37  114.000000  1366.860000            20                     35
# 29  101.000000   796.890000            20                     10
# 44  103.000000  1634.610000            20                     15
# 1    97.000000  1539.390000            15                      6
# 21   94.000000  1127.060000            15                     35
# 2    98.000000   773.220000            15                      6
# 47  102.000000  1618.740000            20                     50
# 39   97.929825  1164.522105            20                     10
# 35   89.000000  1067.110000            10                     25
# 23   95.000000   749.550000            15                     10
# 49   97.929825  1164.522105            10                      6
# 10   97.000000  1539.390000            15                     15
# 22   98.000000  1555.260000            15                     50
# 18   87.000000  1043.130000            10                     35
# 59   97.929825  1164.522105            10                     10
# 20  102.000000   804.780000            20                     50
# 7   101.000000  1602.870000            20                     15
# 42   98.000000  1555.260000            15                     15
# 14   97.000000   765.330000            15                     25
# 28   94.000000  1491.780000            10                      6
# 51  104.000000   820.560000            20                      6
# 38  113.000000  1354.870000            20                      6
#
#     Customer Lifetime(Days)
# 31                        0
# 3                         0
# 52                      595
# 17                      614
# 8                       870
# 6                         0
# 40                    11730
# 4                     11226
# 43                    11071
# 19                    10659
# 34                        0
# 58                      549
# 25                    11495
# 56                      791
# 15                        0
# 27                        0
# 9                         0
# 30                        0
# 26                      635
# 16                    10430
# 24                        0
# 55                      779
# 11                      636
# 32                        0
# 53                      985
# 41                    10283
# 37                        0
# 29                      622
# 44                    10600
# 1                     11189
# 21                        0
# 2                       548
# 47                    10898
# 39                        0
# 35                        0
# 23                      665
# 49                    10742
# 10                    11176
# 22                    10344
# 18                        0
# 59                      568
# 20                      524
# 7                     11082
# 42                    11737
# 14                      575
# 28                    10185
# 51                      912
# 38                        0
# 31    0
# 3     0
# 52    1
# 17    1
# 8     1
# 6     1
# 40    0
# 4     0
# 43    0
# 19    1
# 34    1
# 58    0
# 25    0
# 56    1
# 15    1
# 27    0
# 9     1
# 30    0
# 26    0
# 16    1
# 24    0
# 55    1
# 11    1
# 32    1
# 53    1
# 41    0
# 37    1
# 29    1
# 44    1
# 1     0
# 21    1
# 2     0
# 47    1
# 39    0
# 35    1
# 23    0
# 49    0
# 10    1
# 22    1
# 18    1
# 59    1
# 20    1
# 7     1
# 42    0
# 14    1
# 28    0
# 51    0
# 38    0
# Name: Churn, dtype: int64
